# %%
import sklearn as sk
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder
import math
import joblib as jb
from sklearn.model_selection import train_test_split as tts

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"E:\ml datasets\Melbourne_housing_FULL.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.nunique(
)
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
df=df.drop(['Address','Date','Postcode','YearBuilt','Lattitude','Longtitude'],axis='columns')

# %%
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
row=['Propertycount','Distance','Bedroom2','Bathroom','Car']
df[row]=df[row].fillna(0)

# %%
df['Landsize']=df['Landsize'].fillna(df['Landsize'].mean())
df['BuildingArea']=df['Landsize'].fillna(df['BuildingArea'].mean())

# %%
df.dropna(inplace=True)

# %%
df=pd.get_dummies(df,drop_first=True)
df=df.astype(int)

# %%
x_train,x_test,y_train,y_test=tts(df.drop(['Price'],axis='columns'),df.Price,test_size=0.3)

# %%
mod=LinearRegression().fit(x_train,y_train)
mod.score(x_test,y_test)
# Out:
# -16162451.766222214

# %%
mod.score(x_train,y_train)
# Out:
# 0.6750661618813942

# %%
from sklearn.linear_model import Lasso
modl=Lasso(alpha=100, max_iter=10,tol=0.1)

# %%
modl.fit(x_train,y_train)
modl.score(x_test,y_test)
# Out:
# 0.6824665845098314

# %%
from sklearn.linear_model import Ridge
model=Ridge(alpha=50, max_iter=100,tol=0.1)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6743105354108881

# %%
# i just used this dataset as youtuber recommeded but the nomal linear 
#regreesion an this tends to give same and good output so there is no need 
#of using l1 and l2 here but in some cas you will need it to reduce the 
#bais and varience

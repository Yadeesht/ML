# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
from sklearn.metrics import confusion_matrix as cm
from sklearn.datasets import load_iris

# %%
df=load_iris()

# %%
dir(df)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
x_train, x_test, y_train, y_test=tts(df.data,df.target,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x_train, x_test, y_train, y_test=tts(df.data,df.target,test_size=0.2)
#
# NameError: name 'tts' is not defined

# %%
model=svm.SVC(gamma='auto')

# %%
model.fit(x_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
y_p=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.score(x_train,y_train)
# Out:
# 0.9916666666666667

# %%
c=cm(y_test,y_p)
sns.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
## digit data set

# %%
from sklearn.datasets import load_digits
d=load_digits()

# %%
for i in range(5):
    plt.matshow(d.images[i])

# %%
d.target[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
mod=svm.SVC()

# %%
x_tra, x_tes, y_tra, y_tes=tts(d.data,d.target,test_size=0.2)

# %%
mod.fit(x_tra,y_tra)
# Out:
# SVC()

# %%
y_p=mod.predict(x_tes)

# %%
mod.score(x_tes,y_p)
# Out:
# 1.0

# %%
mod.score(x_tes,y_tes)
# Out:
# 1.0

# %%
cc=cm(y_tes,y_p)

# %%
sns.heatmap(cc,annot=True)
plt.show()
